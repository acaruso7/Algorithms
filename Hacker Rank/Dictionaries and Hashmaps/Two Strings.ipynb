# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def twoStrings(s1,s2):
    for char in s1:
        if char in s2:
            return 'YES'
        else:
            pass
    return 'NO'
    
    
s1 = 'hello'
s2 = 'world'

print(twoStrings(s1, s2))
# Out:
# YES
