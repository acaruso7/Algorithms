# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def rotLeft(a, d):
    for i in range(d):
        a.append(a[i]) #append the d leftmost elements to the end of the list
    a = a[d:] #remove those same d leftmost elements from the beginning of the list
    return a
    
a = [1,2,3,4,5]
d = 4

print(rotLeft(a, d))
# Out:
# [5, 1, 2, 3, 4]
